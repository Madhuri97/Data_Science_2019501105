# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
basics = pd.read_csv("title_basics_data.tsv", delimiter = "\t")
basics.head(30)
# Out:
#        tconst titleType                                   primaryTitle  \
# 0   tt0000001     short                                     Carmencita
# 1   tt0000002     short                         Le clown et ses chiens
# 2   tt0000003     short                                 Pauvre Pierrot
# 3   tt0000004     short                                    Un bon bock
# 4   tt0000005     short                               Blacksmith Scene
# 5   tt0000006     short                              Chinese Opium Den
# 6   tt0000007     short    Corbett and Courtney Before the Kinetograph
# 7   tt0000008     short         Edison Kinetoscopic Record of a Sneeze
# 8   tt0000009     short                                     Miss Jerry
# 9   tt0000010     short                            Leaving the Factory
# 10  tt0000011     short                        Akrobatisches Potpourri
# 11  tt0000012     short                         The Arrival of a Train
# 12  tt0000013     short    The Photographical Congress Arrives in Lyon
# 13  tt0000014     short                            The Waterer Watered
# 14  tt0000015     short                            Autour d'une cabine
# 15  tt0000016     short                         Barque sortant du port
# 16  tt0000017     short                       Italienischer Bauerntanz
# 17  tt0000018     short                           Das boxende Känguruh
# 18  tt0000019     short                               The Clown Barber
# 19  tt0000020     short                                 The Derby 1895
# 20  tt0000022     short                               Blacksmith Scene
# 21  tt0000023     short                                        The Sea
# 22  tt0000024     short                      Opening of the Kiel Canal
# 23  tt0000025     short  The Oxford and Cambridge University Boat Race
# 24  tt0000026     short                  The Messers. Lumière at Cards
# 25  tt0000027     short                     Cordeliers' Square in Lyon
# 26  tt0000028     short                           Fishing for Goldfish
# 27  tt0000029     short                                  Baby's Dinner
# 28  tt0000030     short                             Rough Sea at Dover
# 29  tt0000031     short                            Jumping the Blanket
#
#                                         originalTitle isAdult startYear  \
# 0                                          Carmencita       0      1894
# 1                              Le clown et ses chiens       0      1892
# 2                                      Pauvre Pierrot       0      1892
# 3                                         Un bon bock       0      1892
# 4                                    Blacksmith Scene       0      1893
# 5                                   Chinese Opium Den       0      1894
# 6         Corbett and Courtney Before the Kinetograph       0      1894
# 7              Edison Kinetoscopic Record of a Sneeze       0      1894
# 8                                          Miss Jerry       0      1894
# 9                 La sortie de l'usine Lumière à Lyon       0      1895
# 10                            Akrobatisches Potpourri       0      1895
# 11                   L'arrivée d'un train à La Ciotat       0      1896
# 12  Neuville-sur-Saône: Débarquement du congrès de...       0      1895
# 13                                  L'arroseur arrosé       0      1895
# 14                                Autour d'une cabine       0      1894
# 15                             Barque sortant du port       0      1895
# 16                           Italienischer Bauerntanz       0      1895
# 17                               Das boxende Känguruh       0      1895
# 18                                   The Clown Barber       0      1898
# 19                                     The Derby 1895       0      1895
# 20                                      Les forgerons       0      1895
# 21                                    Baignade en mer       0      1895
# 22                          Opening of the Kiel Canal       0      1895
# 23      The Oxford and Cambridge University Boat Race       0      1895
# 24                                    Partie d'écarté       0      1896
# 25                        Place des Cordeliers à Lyon       0      1895
# 26                       La pêche aux poissons rouges       0      1895
# 27                                      Repas de bébé       0      1895
# 28                                 Rough Sea at Dover       0      1895
# 29                            Le saut à la couverture       0      1895
#
#    endYear runtimeMinutes                    genres
# 0       \N              1         Documentary,Short
# 1       \N              5           Animation,Short
# 2       \N              4  Animation,Comedy,Romance
# 3       \N             12           Animation,Short
# 4       \N              1              Comedy,Short
# 5       \N              1                     Short
# 6       \N              1               Short,Sport
# 7       \N              1         Documentary,Short
# 8       \N             45             Romance,Short
# 9       \N              1         Documentary,Short
# 10      \N              1         Documentary,Short
# 11      \N              1         Documentary,Short
# 12      \N              1         Documentary,Short
# 13      \N              1              Comedy,Short
# 14      \N              2           Animation,Short
# 15      \N              1         Documentary,Short
# 16      \N              1         Documentary,Short
# 17      \N              1                     Short
# 18      \N             \N              Comedy,Short
# 19      \N              1   Documentary,Short,Sport
# 20      \N              1         Documentary,Short
# 21      \N              1         Documentary,Short
# 22      \N             \N                News,Short
# 23      \N             \N          News,Short,Sport
# 24      \N              1         Documentary,Short
# 25      \N              1         Documentary,Short
# 26      \N              1         Documentary,Short
# 27      \N              1         Documentary,Short
# 28      \N              1         Documentary,Short
# 29      \N              1         Documentary,Short

# %%
ratings = pd.read_csv("rating_data.tsv", delimiter = "\t")
ratings.head(5)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.6      1668
# 1  tt0000002            6.1       207
# 2  tt0000003            6.5      1392
# 3  tt0000004            6.2       123
# 4  tt0000005            6.2      2179

# %%
data = ratings[ratings['averageRating'] > 8.0]
data.head(5)
# Out:
#         tconst  averageRating  numVotes
# 273  tt0000361            8.1        10
# 298  tt0000417            8.2     43785
# 338  tt0000505            8.1        11
# 606  tt0000961            8.2        13
# 686  tt0001089            8.3        19

# %%
final_ratings = data.sort_values('numVotes', ascending = False)

# %%
final_ratings.head(20)
# Out:
#            tconst  averageRating  numVotes
# 81763   tt0111161            9.3   2324705
# 245941  tt0468569            9.0   2286538
# 581337  tt1375666            8.8   2050103
# 98028   tt0137523            8.8   1841325
# 81547   tt0110912            8.9   1813205
# 80674   tt0109830            8.8   1793487
# 423361  tt0944947            9.3   1745723
# 95950   tt0133093            8.7   1663688
# 89533   tt0120737            8.8   1648332
# 112825  tt0167260            8.9   1631652
# 45692   tt0068646            9.2   1606062
# 573924  tt1345836            8.4   1506463
# 387373  tt0816692            8.6   1495006
# 112826  tt0167261            8.7   1475172
# 413506  tt0903747            9.5   1437859
# 84315   tt0114369            8.6   1432983
# 665864  tt1853728            8.4   1346225
# 115246  tt0172495            8.5   1332104
# 206276  tt0372784            8.2   1300069
# 74983   tt0102926            8.6   1260893

# %%
output = pd.merge(final_ratings, basics, on= 'tconst')
output.head(10)
# Out:
#       tconst  averageRating  numVotes titleType  \
# 0  tt0111161            9.3   2324705     movie
# 1  tt0468569            9.0   2286538     movie
# 2  tt1375666            8.8   2050103     movie
# 3  tt0137523            8.8   1841325     movie
# 4  tt0110912            8.9   1813205     movie
# 5  tt0109830            8.8   1793487     movie
# 6  tt0944947            9.3   1745723  tvSeries
# 7  tt0133093            8.7   1663688     movie
# 8  tt0120737            8.8   1648332     movie
# 9  tt0167260            8.9   1631652     movie
#
#                                         primaryTitle  \
# 0                           The Shawshank Redemption
# 1                                    The Dark Knight
# 2                                          Inception
# 3                                         Fight Club
# 4                                       Pulp Fiction
# 5                                       Forrest Gump
# 6                                    Game of Thrones
# 7                                         The Matrix
# 8  The Lord of the Rings: The Fellowship of the Ring
# 9      The Lord of the Rings: The Return of the King
#
#                                        originalTitle isAdult startYear  \
# 0                           The Shawshank Redemption       0      1994
# 1                                    The Dark Knight       0      2008
# 2                                          Inception       0      2010
# 3                                         Fight Club       0      1999
# 4                                       Pulp Fiction       0      1994
# 5                                       Forrest Gump       0      1994
# 6                                    Game of Thrones       0      2011
# 7                                         The Matrix       0      1999
# 8  The Lord of the Rings: The Fellowship of the Ring       0      2001
# 9      The Lord of the Rings: The Return of the King       0      2003
#
#   endYear runtimeMinutes                   genres
# 0      \N            142                    Drama
# 1      \N            152       Action,Crime,Drama
# 2      \N            148  Action,Adventure,Sci-Fi
# 3      \N            139                    Drama
# 4      \N            154              Crime,Drama
# 5      \N            142            Drama,Romance
# 6    2019             57   Action,Adventure,Drama
# 7      \N            136            Action,Sci-Fi
# 8      \N            178   Action,Adventure,Drama
# 9      \N            201   Action,Adventure,Drama

# %%
output = output[output['titleType'] == 'movie']

# %%
output.head(10)
# Out:
#        tconst  averageRating  numVotes titleType  \
# 0   tt0111161            9.3   2324705     movie
# 1   tt0468569            9.0   2286538     movie
# 2   tt1375666            8.8   2050103     movie
# 3   tt0137523            8.8   1841325     movie
# 4   tt0110912            8.9   1813205     movie
# 5   tt0109830            8.8   1793487     movie
# 7   tt0133093            8.7   1663688     movie
# 8   tt0120737            8.8   1648332     movie
# 9   tt0167260            8.9   1631652     movie
# 10  tt0068646            9.2   1606062     movie
#
#                                          primaryTitle  \
# 0                            The Shawshank Redemption
# 1                                     The Dark Knight
# 2                                           Inception
# 3                                          Fight Club
# 4                                        Pulp Fiction
# 5                                        Forrest Gump
# 7                                          The Matrix
# 8   The Lord of the Rings: The Fellowship of the Ring
# 9       The Lord of the Rings: The Return of the King
# 10                                      The Godfather
#
#                                         originalTitle isAdult startYear  \
# 0                            The Shawshank Redemption       0      1994
# 1                                     The Dark Knight       0      2008
# 2                                           Inception       0      2010
# 3                                          Fight Club       0      1999
# 4                                        Pulp Fiction       0      1994
# 5                                        Forrest Gump       0      1994
# 7                                          The Matrix       0      1999
# 8   The Lord of the Rings: The Fellowship of the Ring       0      2001
# 9       The Lord of the Rings: The Return of the King       0      2003
# 10                                      The Godfather       0      1972
#
#    endYear runtimeMinutes                   genres
# 0       \N            142                    Drama
# 1       \N            152       Action,Crime,Drama
# 2       \N            148  Action,Adventure,Sci-Fi
# 3       \N            139                    Drama
# 4       \N            154              Crime,Drama
# 5       \N            142            Drama,Romance
# 7       \N            136            Action,Sci-Fi
# 8       \N            178   Action,Adventure,Drama
# 9       \N            201   Action,Adventure,Drama
# 10      \N            175              Crime,Drama

# %%
output['originalTitle'].head(20)
# Out:
# 0                              The Shawshank Redemption
# 1                                       The Dark Knight
# 2                                             Inception
# 3                                            Fight Club
# 4                                          Pulp Fiction
# 5                                          Forrest Gump
# 7                                            The Matrix
# 8     The Lord of the Rings: The Fellowship of the Ring
# 9         The Lord of the Rings: The Return of the King
# 10                                        The Godfather
# 11                                The Dark Knight Rises
# 12                                         Interstellar
# 13                The Lord of the Rings: The Two Towers
# 15                                                Se7en
# 16                                     Django Unchained
# 17                                            Gladiator
# 18                                        Batman Begins
# 19                             The Silence of the Lambs
# 20                                 Inglourious Basterds
# 21                                  Saving Private Ryan
# Name: originalTitle, dtype: object

# %%
basics.dtypes
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           object
# startYear         object
# endYear           object
# runtimeMinutes    object
# genres            object
# dtype: object

# %%
basics['startYear'] = pd.to_numeric(basics['startYear'], errors='coerce')

# %%
basics.dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult            object
# startYear         float64
# endYear            object
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
year = basics[(basics['startYear'] >= 2000) & (basics['titleType'] == 'movie')]
year.head(10)
# Out:
#           tconst titleType                               primaryTitle  \
# 15184  tt0015414     movie                     La tierra de los toros
# 16662  tt0016906     movie                                 Frivolinas
# 19706  tt0019996     movie                                    Hongxia
# 34811  tt0035423     movie                             Kate & Leopold
# 61132  tt0062336     movie  El Tango del Viudo y Su Espejo Deformante
# 63462  tt0064730     movie                 Japan Organized Crime Boss
# 64107  tt0065392     movie                         Bucharest Memories
# 67686  tt0069049     movie                 The Other Side of the Wind
# 85714  tt0087608     movie                           Leila wa al ziap
# 86825  tt0088751     movie                          The Naked Monster
#
#                                    originalTitle isAdult  startYear endYear  \
# 15184                     La tierra de los toros       0     2000.0      \N
# 16662                                 Frivolinas       0     2014.0      \N
# 19706                                    Hongxia       0     2011.0      \N
# 34811                             Kate & Leopold       0     2001.0      \N
# 61132  El Tango del Viudo y Su Espejo Deformante       0     2020.0      \N
# 63462                 Nihon boryoku-dan: Kumicho       0     2000.0      \N
# 64107                       Amintiri bucurestene       0     2020.0      \N
# 67686                 The Other Side of the Wind       0     2018.0      \N
# 85714                           Leila wa al ziap       0     2008.0      \N
# 86825                          The Naked Monster       0     2005.0      \N
#
#       runtimeMinutes                  genres
# 15184             60                      \N
# 16662             80          Comedy,Musical
# 19706             94                      \N
# 34811            118  Comedy,Fantasy,Romance
# 61132             70                   Drama
# 63462             97            Action,Crime
# 64107             \N             Documentary
# 67686            122                   Drama
# 85714             90             Documentary
# 86825            100    Comedy,Horror,Sci-Fi

# %%
output1 = pd.merge(year, ratings, on= 'tconst')
output1.head(10)
# Out:
#       tconst titleType                               primaryTitle  \
# 0  tt0015414     movie                     La tierra de los toros
# 1  tt0016906     movie                                 Frivolinas
# 2  tt0019996     movie                                    Hongxia
# 3  tt0035423     movie                             Kate & Leopold
# 4  tt0062336     movie  El Tango del Viudo y Su Espejo Deformante
# 5  tt0064730     movie                 Japan Organized Crime Boss
# 6  tt0065392     movie                         Bucharest Memories
# 7  tt0069049     movie                 The Other Side of the Wind
# 8  tt0087608     movie                           Leila wa al ziap
# 9  tt0088751     movie                          The Naked Monster
#
#                                originalTitle isAdult  startYear endYear  \
# 0                     La tierra de los toros       0     2000.0      \N
# 1                                 Frivolinas       0     2014.0      \N
# 2                                    Hongxia       0     2011.0      \N
# 3                             Kate & Leopold       0     2001.0      \N
# 4  El Tango del Viudo y Su Espejo Deformante       0     2020.0      \N
# 5                 Nihon boryoku-dan: Kumicho       0     2000.0      \N
# 6                       Amintiri bucurestene       0     2020.0      \N
# 7                 The Other Side of the Wind       0     2018.0      \N
# 8                           Leila wa al ziap       0     2008.0      \N
# 9                          The Naked Monster       0     2005.0      \N
#
#   runtimeMinutes                  genres  averageRating  numVotes
# 0             60                      \N            5.4        11
# 1             80          Comedy,Musical            5.6        15
# 2             94                      \N            6.3        52
# 3            118  Comedy,Fantasy,Romance            6.4     78683
# 4             70                   Drama            6.4       125
# 5             97            Action,Crime            7.0       172
# 6             \N             Documentary            6.3         7
# 7            122                   Drama            6.8      6190
# 8             90             Documentary            7.7        13
# 9            100    Comedy,Horror,Sci-Fi            5.4       274

# %%
votes = output1[output1['numVotes'] > 40000]
votes.head(10)
# Out:
#        tconst titleType                                       primaryTitle  \
# 3   tt0035423     movie                                     Kate & Leopold
# 39  tt0118694     movie                               In the Mood for Love
# 66  tt0120630     movie                                        Chicken Run
# 67  tt0120667     movie                                     Fantastic Four
# 69  tt0120679     movie                                              Frida
# 70  tt0120681     movie                                          From Hell
# 73  tt0120737     movie  The Lord of the Rings: The Fellowship of the Ring
# 75  tt0120755     movie                             Mission: Impossible II
# 76  tt0120804     movie                                      Resident Evil
# 80  tt0120903     movie                                              X-Men
#
#                                         originalTitle isAdult  startYear  \
# 3                                      Kate & Leopold       0     2001.0
# 39                                   Fa yeung nin wah       0     2000.0
# 66                                        Chicken Run       0     2000.0
# 67                                     Fantastic Four       0     2005.0
# 69                                              Frida       0     2002.0
# 70                                          From Hell       0     2001.0
# 73  The Lord of the Rings: The Fellowship of the Ring       0     2001.0
# 75                             Mission: Impossible II       0     2000.0
# 76                                      Resident Evil       0     2002.0
# 80                                              X-Men       0     2000.0
#
#    endYear runtimeMinutes                      genres  averageRating  numVotes
# 3       \N            118      Comedy,Fantasy,Romance            6.4     78683
# 39      \N             98               Drama,Romance            8.1    122948
# 66      \N             84  Adventure,Animation,Comedy            7.0    176309
# 67      \N            106    Action,Adventure,Fantasy            5.7    310529
# 69      \N            123     Biography,Drama,Romance            7.4     80987
# 70      \N            122     Horror,Mystery,Thriller            6.8    146310
# 73      \N            178      Action,Adventure,Drama            8.8   1648332
# 75      \N            123   Action,Adventure,Thriller            6.1    313130
# 76      \N            100        Action,Horror,Sci-Fi            6.7    246545
# 80      \N            104     Action,Adventure,Sci-Fi            7.4    568306

# %%
Output2 = votes.sort_values('averageRating', ascending = False)
Output2.head(20)
# Out:
#             tconst titleType  \
# 78605    tt2592910     movie
# 20010    tt0468569     movie
# 366      tt0167260     movie
# 47519    tt1375666     movie
# 73       tt0120737     movie
# 111682   tt5813916     movie
# 367      tt0167261     movie
# 30106   tt10189514     movie
# 7552     tt0317248     movie
# 2348     tt0245429     movie
# 24723    tt0816692     movie
# 129909   tt8503618     movie
# 119393   tt6751668     movie
# 21428    tt0482571     movie
# 2800     tt0253474     movie
# 78488    tt2582802     movie
# 122881   tt7286456     movie
# 48894    tt1424432     movie
# 14632    tt0407887     movie
# 56744    tt1675434     movie
#
#                                              primaryTitle  \
# 78605                              CM101MMXI Fundamentals
# 20010                                     The Dark Knight
# 366         The Lord of the Rings: The Return of the King
# 47519                                           Inception
# 73      The Lord of the Rings: The Fellowship of the Ring
# 111682                                    The Mountain II
# 367                 The Lord of the Rings: The Two Towers
# 30106                                     Soorarai Pottru
# 7552                                          City of God
# 2348                                        Spirited Away
# 24723                                        Interstellar
# 129909                                           Hamilton
# 119393                                           Parasite
# 21428                                        The Prestige
# 2800                                          The Pianist
# 78488                                            Whiplash
# 122881                                              Joker
# 48894                                               Senna
# 14632                                        The Departed
# 56744                                    The Intouchables
#
#                                             originalTitle isAdult  startYear  \
# 78605                              CM101MMXI Fundamentals       0     2013.0
# 20010                                     The Dark Knight       0     2008.0
# 366         The Lord of the Rings: The Return of the King       0     2003.0
# 47519                                           Inception       0     2010.0
# 73      The Lord of the Rings: The Fellowship of the Ring       0     2001.0
# 111682                                             Dag II       0     2016.0
# 367                 The Lord of the Rings: The Two Towers       0     2002.0
# 30106                                     Soorarai Pottru       0     2020.0
# 7552                                       Cidade de Deus       0     2002.0
# 2348                        Sen to Chihiro no kamikakushi       0     2001.0
# 24723                                        Interstellar       0     2014.0
# 129909                                           Hamilton       0     2020.0
# 119393                                       Gisaengchung       0     2019.0
# 21428                                        The Prestige       0     2006.0
# 2800                                          The Pianist       0     2002.0
# 78488                                            Whiplash       0     2014.0
# 122881                                              Joker       0     2019.0
# 48894                                               Senna       0     2010.0
# 14632                                        The Departed       0     2006.0
# 56744                                        Intouchables       0     2011.0
#
#        endYear runtimeMinutes                       genres  averageRating  \
# 78605       \N            139           Comedy,Documentary            9.2
# 20010       \N            152           Action,Crime,Drama            9.0
# 366         \N            201       Action,Adventure,Drama            8.9
# 47519       \N            148      Action,Adventure,Sci-Fi            8.8
# 73          \N            178       Action,Adventure,Drama            8.8
# 111682      \N            135             Action,Drama,War            8.8
# 367         \N            179       Action,Adventure,Drama            8.7
# 30106       \N            153                        Drama            8.7
# 7552        \N            130                  Crime,Drama            8.6
# 2348        \N            125   Adventure,Animation,Family            8.6
# 24723       \N            169       Adventure,Drama,Sci-Fi            8.6
# 129909      \N            160      Biography,Drama,History            8.6
# 119393      \N            132        Comedy,Drama,Thriller            8.6
# 21428       \N            130         Drama,Mystery,Sci-Fi            8.5
# 2800        \N            150        Biography,Drama,Music            8.5
# 78488       \N            106                  Drama,Music            8.5
# 122881      \N            122         Crime,Drama,Thriller            8.5
# 48894       \N            106  Biography,Documentary,Sport            8.5
# 14632       \N            151         Crime,Drama,Thriller            8.5
# 56744       \N            112       Biography,Comedy,Drama            8.5
#
#         numVotes
# 78605      43804
# 20010    2286538
# 366      1631652
# 47519    2050103
# 73       1648332
# 111682    104721
# 367      1475172
# 30106      51444
# 7552      695667
# 2348      644324
# 24723    1495006
# 129909     50964
# 119393    528416
# 21428    1180732
# 2800      723566
# 78488     709823
# 122881    917812
# 48894      63816
# 14632    1180900
# 56744     752392

# %%
Output2['originalTitle'].head(20)
# Out:
# 78605                                CM101MMXI Fundamentals
# 20010                                       The Dark Knight
# 366           The Lord of the Rings: The Return of the King
# 47519                                             Inception
# 73        The Lord of the Rings: The Fellowship of the Ring
# 111682                                               Dag II
# 367                   The Lord of the Rings: The Two Towers
# 30106                                       Soorarai Pottru
# 7552                                         Cidade de Deus
# 2348                          Sen to Chihiro no kamikakushi
# 24723                                          Interstellar
# 129909                                             Hamilton
# 119393                                         Gisaengchung
# 21428                                          The Prestige
# 2800                                            The Pianist
# 78488                                              Whiplash
# 122881                                                Joker
# 48894                                                 Senna
# 14632                                          The Departed
# 56744                                          Intouchables
# Name: originalTitle, dtype: object
